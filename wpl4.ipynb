# %% [markdown]
#  <img src="https://github.com/MahendraCherukupalli/The-Sparks-Foundation-Internship/blob/master/wpl_badge1.png?raw=true"/>

# %% [markdown]
# ## Steps:
# - Import Libraries
# - Get the Data
# - Data Preprocessing
# - Train-Test Split
# - Scalling the Data
# - Creating and Training the Model
# - Predictions
# - Residual Analysis
# - Evaluating the modelm

# %% [markdown]
# **Let's get started!**

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
data=pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data1=pd.read_csv("deliveries.csv")
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.shape
# Out:
# (179078, 21)

# %%
data1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# checking for null values...
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Dc=data["team1"]=='Delhi Daredevils'
Rr=data["team1"]=='Rajasthan Royals'
Dc1=data["team2"]=='Delhi Daredevils'
Rr1=data["team2"]=='Rajasthan Royals'

# %%
rdf=data[(Dc & Rr1)|(Dc1 & Rr)]

# %%
rdf
# Out:
#        id  season          city        date             team1  \
# 61     62    2008         Delhi  2008-04-19  Rajasthan Royals
# 92     93    2008        Jaipur  2008-05-11  Delhi Daredevils
# 114   115    2008        Mumbai  2008-05-30  Rajasthan Royals
# 132   133    2009     Centurion  2009-04-28  Delhi Daredevils
# 164   165    2009  Bloemfontein  2009-05-17  Delhi Daredevils
# 179   180    2010     Ahmedabad  2010-03-15  Rajasthan Royals
# 202   203    2010         Delhi  2010-03-31  Delhi Daredevils
# 240   241    2011        Jaipur  2011-04-12  Delhi Daredevils
# 344   345    2012         Delhi  2012-04-29  Delhi Daredevils
# 348   349    2012        Jaipur  2012-05-01  Rajasthan Royals
# 384   385    2013         Delhi  2013-04-06  Rajasthan Royals
# 432   433    2013        Jaipur  2013-05-07  Delhi Daredevils
# 479   480    2014         Delhi  2014-05-03  Delhi Daredevils
# 497   498    2014     Ahmedabad  2014-05-15  Rajasthan Royals
# ...

# %%
rdf.shape
# Out:
# (18, 18)

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]]
# Out:
#                 team1             team2       toss_winner toss_decision  \
# 61   Rajasthan Royals  Delhi Daredevils  Rajasthan Royals           bat
# 92   Delhi Daredevils  Rajasthan Royals  Rajasthan Royals         field
# 114  Rajasthan Royals  Delhi Daredevils  Delhi Daredevils         field
# 132  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# 164  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# 179  Rajasthan Royals  Delhi Daredevils  Delhi Daredevils         field
# 202  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# 240  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# 344  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# 348  Rajasthan Royals  Delhi Daredevils  Rajasthan Royals           bat
# 384  Rajasthan Royals  Delhi Daredevils  Rajasthan Royals           bat
# 432  Delhi Daredevils  Rajasthan Royals  Delhi Daredevils           bat
# ...

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]].isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %% [markdown]
# # 1

# %%
rdf[(rdf["toss_winner"]=="Delhi Daredevils")&(rdf["toss_decision"]=="bat")]
# Out:
#       id  season          city        date             team1  \
# 132  133    2009     Centurion  2009-04-28  Delhi Daredevils
# 164  165    2009  Bloemfontein  2009-05-17  Delhi Daredevils
# 202  203    2010         Delhi  2010-03-31  Delhi Daredevils
# 240  241    2011        Jaipur  2011-04-12  Delhi Daredevils
# 344  345    2012         Delhi  2012-04-29  Delhi Daredevils
# 432  433    2013        Jaipur  2013-05-07  Delhi Daredevils
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 132  Rajasthan Royals  Delhi Daredevils           bat  normal           0
# 164  Rajasthan Royals  Delhi Daredevils           bat  normal           0
# 202  Rajasthan Royals  Delhi Daredevils           bat  normal           0
# 240  Rajasthan Royals  Delhi Daredevils           bat  normal           0
# 344  Rajasthan Royals  Delhi Daredevils           bat  normal           0
# 432  Rajasthan Royals  Delhi Daredevils           bat  normal           0
#
# ...

# %%
rdf["winner"].value_counts()
# Out:
# Rajasthan Royals    11
# Delhi Daredevils     7
# Name: winner, dtype: int64

# %% [markdown]
# # 2

# %%
runs=data1[(data1["batting_team"]=="Delhi Daredevils")&(data1["bowling_team"]=="Rajasthan Royals")]

# %%
runs1=runs[runs["over"].isin([1,2,3,4,5,6])]

# %%
runs1.groupby(["match_id"])["total_runs"].count()
# Out:
# match_id
# 62      38
# 93      37
# 115     39
# 133     37
# 165     38
# 180     39
# 203     38
# 241     38
# 345     37
# 349     36
# 385     37
# 433     39
# 480     36
# 498     37
# 523     37
# 553     40
# 7899    37
# 7925    36
# Name: total_runs, dtype: int64

# %% [markdown]
# average of 36 runs scored by Dc in powerplay.

# %% [markdown]
# # 3

# %%
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
bat=data1[(data1["batting_team"]=='Rajasthan Royals')&(data1["bowling_team"]=="Delhi Daredevils")&(data1["batsman"]=="SPD Smith")]

# %%
bat.head(80)
# Out:
#         match_id  inning      batting_team      bowling_team  over  ball  \
# 124099       523       2  Rajasthan Royals  Delhi Daredevils     6     3
# 124100       523       2  Rajasthan Royals  Delhi Daredevils     6     4
# 124101       523       2  Rajasthan Royals  Delhi Daredevils     6     5
# 124102       523       2  Rajasthan Royals  Delhi Daredevils     6     6
# 124105       523       2  Rajasthan Royals  Delhi Daredevils     7     3
# 124107       523       2  Rajasthan Royals  Delhi Daredevils     7     5
# 124108       523       2  Rajasthan Royals  Delhi Daredevils     7     6
# 124109       523       2  Rajasthan Royals  Delhi Daredevils     8     1
# 124110       523       2  Rajasthan Royals  Delhi Daredevils     8     2
#
#           batsman non_striker           bowler  is_super_over  ...  bye_runs  \
# 124099  SPD Smith   AM Rahane  NM Coulter-Nile              0  ...         0
# 124100  SPD Smith   AM Rahane  NM Coulter-Nile              0  ...         0
# ...

# %%
bat.shape
# Out:
# (9, 21)

# %%
bat.groupby(["over"])["batsman_runs"].sum()
# Out:
# over
# 6    4
# 7    6
# 8    0
# Name: batsman_runs, dtype: int64

# %%
bat.groupby(["match_id"])["batsman_runs"].sum()
# Out:
# match_id
# 523    10
# Name: batsman_runs, dtype: int64

# %%
bat["batsman_runs"].sum()
# Out:
# 10

# %%
(bat["batsman_runs"].sum())/1
# Out:
# 10.0

# %%
bat["player_dismissed"].value_counts()
# Out:
# SPD Smith    1
# Name: player_dismissed, dtype: int64

# %% [markdown]
# we dont have enough information to answer this question.

# %% [markdown]
# # 4

# %%
wide=data1[(data1["batting_team"].isin(['Delhi Daredevils',"Rajasthan Royals"]))&(data1["bowling_team"].isin(['Delhi Daredevils',"Rajasthan Royals"]))]

# %%
wide
# Out:
#         match_id  inning      batting_team      bowling_team  over  ball  \
# 14335         62       1  Rajasthan Royals  Delhi Daredevils     1     1
# 14336         62       1  Rajasthan Royals  Delhi Daredevils     1     2
# 14337         62       1  Rajasthan Royals  Delhi Daredevils     1     3
# 14338         62       1  Rajasthan Royals  Delhi Daredevils     1     4
# 14339         62       1  Rajasthan Royals  Delhi Daredevils     1     5
# ...          ...     ...               ...               ...   ...   ...
# 158034      7925       2  Rajasthan Royals  Delhi Daredevils    12     3
# 158035      7925       2  Rajasthan Royals  Delhi Daredevils    12     4
# 158036      7925       2  Rajasthan Royals  Delhi Daredevils    12     5
# 158037      7925       2  Rajasthan Royals  Delhi Daredevils    12     6
# 158038      7925       2  Rajasthan Royals  Delhi Daredevils    12     7
#
#             batsman  non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
wide.groupby(["match_id"])["wide_runs"].value_counts()
# Out:
# match_id  wide_runs
# 62        0            211
#           1              6
#           2              1
#           5              1
# 93        0            237
#           1              7
#           2              1
# 115       0            217
#           1              5
#           2              1
# 133       0            234
#           1              6
# 165       0            245
#           1              6
# 180       0            223
#           1              8
#           2              1
# 203       0            227
#           1              5
#           2              1
# 241       0            234
#           1              4
# 345       0            240
#           1              7
# 349       0            212
#           1              4
# 385       0            240
#           1              7
#           5              1
# 433       0            227
#           1              9
#           5              1
# 480       0            231
# ...

# %% [markdown]
# average of 7 wides bowld in each match

# %% [markdown]
# # 5

# %%
wickets=data1[(data1["batting_team"].isin(['Delhi Daredevils',"Rajasthan Royals"]))&(data1["bowling_team"].isin(['Delhi Daredevils',"Rajasthan Royals"]))]

# %%
wickets.groupby(["match_id"])["player_dismissed"].count()
# Out:
# match_id
# 62       9
# 93      14
# 115     19
# 133     12
# 165     12
# 180     10
# 203     16
# 241     10
# 345      9
# 349     10
# 385     13
# 433      5
# 480      8
# 498     15
# 523     10
# 553      9
# 7899     9
# 7925    11
# Name: player_dismissed, dtype: int64

# %% [markdown]
# each team loss average of 5 wickets
