# %% [markdown]
#  <img src="https://github.com/MahendraCherukupalli/The-Sparks-Foundation-Internship/blob/master/wpl_badge1.png?raw=true"/>

# %% [markdown]
# ## Steps:
# - Import Libraries
# - Get the Data
# - Data Preprocessing
# - Train-Test Split
# - Scalling the Data
# - Creating and Training the Model
# - Predictions
# - Residual Analysis
# - Evaluating the modelm

# %% [markdown]
# **Let's get started!**

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
data=pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data1=pd.read_csv("deliveries.csv")
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.shape
# Out:
# (179078, 21)

# %%
data1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# checking for null values...
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
Csk=data["team1"]=='Chennai Super Kings'
Rr=data["team1"]=='Rajasthan Royals'
Csk1=data["team2"]=='Chennai Super Kings'
Rr1=data["team2"]=='Rajasthan Royals'

# %%
rdf=data[(Csk & Rr1)|(Csk1 & Rr)]

# %%
rdf.head()
# Out:
#       id  season       city        date                team1  \
# 82    83    2008     Jaipur  2008-05-04  Chennai Super Kings
# 109  110    2008    Chennai  2008-05-24     Rajasthan Royals
# 116  117    2008     Mumbai  2008-06-01  Chennai Super Kings
# 136  137    2009  Centurion  2009-04-30  Chennai Super Kings
# 151  152    2009  Kimberley  2009-05-09     Rajasthan Royals
#
#                    team2          toss_winner toss_decision  result  \
# 82      Rajasthan Royals  Chennai Super Kings           bat  normal
# 109  Chennai Super Kings     Rajasthan Royals           bat  normal
# 116     Rajasthan Royals     Rajasthan Royals         field  normal
# 136     Rajasthan Royals     Rajasthan Royals         field  normal
# 151  Chennai Super Kings     Rajasthan Royals           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 82            0     Rajasthan Royals            0               8
# ...

# %%
rdf.shape
# Out:
# (21, 18)

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]]
# Out:
#                    team1                team2          toss_winner  \
# 82   Chennai Super Kings     Rajasthan Royals  Chennai Super Kings
# 109     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 116  Chennai Super Kings     Rajasthan Royals     Rajasthan Royals
# 136  Chennai Super Kings     Rajasthan Royals     Rajasthan Royals
# 151     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 197     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 205  Chennai Super Kings     Rajasthan Royals  Chennai Super Kings
# 275     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 284  Chennai Super Kings     Rajasthan Royals     Rajasthan Royals
# 333     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 360     Rajasthan Royals  Chennai Super Kings  Chennai Super Kings
# 409     Rajasthan Royals  Chennai Super Kings     Rajasthan Royals
# 441  Chennai Super Kings     Rajasthan Royals     Rajasthan Royals
# ...

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]].isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %% [markdown]
# # 1

# %%
rdf[(rdf["toss_winner"]=="Chennai Super Kings")&(rdf["toss_decision"]=="bat")]
# Out:
#        id  season       city        date                team1  \
# 82     83    2008     Jaipur  2008-05-04  Chennai Super Kings
# 205   206    2010    Chennai  2010-04-03  Chennai Super Kings
# 532   533    2015  Ahmedabad  2015-04-19  Chennai Super Kings
# 562   563    2015    Chennai  2015-05-10  Chennai Super Kings
# 678  7936    2018     Jaipur    11/05/18  Chennai Super Kings
#
#                 team2          toss_winner toss_decision  result  dl_applied  \
# 82   Rajasthan Royals  Chennai Super Kings           bat  normal           0
# 205  Rajasthan Royals  Chennai Super Kings           bat  normal           0
# 532  Rajasthan Royals  Chennai Super Kings           bat  normal           0
# 562  Rajasthan Royals  Chennai Super Kings           bat  normal           0
# 678  Rajasthan Royals  Chennai Super Kings           bat  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# ...

# %%
rdf["winner"].value_counts()
# Out:
# Chennai Super Kings    14
# Rajasthan Royals        7
# Name: winner, dtype: int64

# %% [markdown]
# according to the dataset Csk win the match

# %% [markdown]
# # 2

# %%
runs=data1[(data1["batting_team"]=="Rajasthan Royals")&(data1["bowling_team"]=="Chennai Super Kings")]

# %%
runs1=runs[runs["over"].isin([1,2,3,4,5,6])]

# %%
runs1.groupby(["match_id"])["total_runs"].count()
# Out:
# match_id
# 83       36
# 110      37
# 117      36
# 137      37
# 152      36
# 198      38
# 206      37
# 276      36
# 285      37
# 334      37
# 361      37
# 410      37
# 442      36
# 467      37
# 494      37
# 533      36
# 563      36
# 7910     38
# 7936     37
# 11148    39
# 11316    37
# Name: total_runs, dtype: int64

# %%
runs1.groupby(["match_id"])["total_runs"].count().mean()
# Out:
# 36.857142857142854

# %% [markdown]
# average of 36 runs scored by RR in powerplay.

# %% [markdown]
# # 3

# %%
ecomony_rate=data1[(data1["batting_team"]=="Rajasthan Royals")&(data1["bowling_team"]=="Chennai Super Kings")&(data1["bowler"]=="DL Chahar")]

# %%
ecomony_rate.head()
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 154358      7910       2  Rajasthan Royals  Chennai Super Kings     1     1
# 154359      7910       2  Rajasthan Royals  Chennai Super Kings     1     2
# 154360      7910       2  Rajasthan Royals  Chennai Super Kings     1     3
# 154361      7910       2  Rajasthan Royals  Chennai Super Kings     1     4
# 154362      7910       2  Rajasthan Royals  Chennai Super Kings     1     5
#
#           batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# 154358  AM Rahane   H Klaasen  DL Chahar              0  ...         0
# 154359  AM Rahane   H Klaasen  DL Chahar              0  ...         0
# 154360  H Klaasen   AM Rahane  DL Chahar              0  ...         0
# 154361  H Klaasen   AM Rahane  DL Chahar              0  ...         0
# 154362  AM Rahane   H Klaasen  DL Chahar              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ecomony_rate.groupby(["match_id","over"])["total_runs"].sum()
# Out:
# match_id  over
# 7910      1       16
#           3        5
#           5        3
#           7       10
# 11148     1        0
#           3        6
#           5        5
#           7        9
# 11316     1       12
#           3       10
#           5        5
#           19       8
# Name: total_runs, dtype: int64

# %%
ecomony_rate.groupby(["match_id","over"])["total_runs"].sum().mean()
# Out:
# 7.416666666666667

# %% [markdown]
# According to dataset Deepak Chahar average economy is 7.4

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# # 4

# %%
Archer_death_wickets=data1[(data1["batting_team"]=="Chennai Super Kings")&(data1["bowling_team"]=="Rajasthan Royals")&(data1["bowler"]=="J Archer")]

# %%
Archer_death_wickets1=Archer_death_wickets[Archer_death_wickets["over"].isin([15,16,17,18,19,20])]

# %%
Archer_death_wickets1.head()
# Out:
#         match_id  inning         batting_team      bowling_team  over  ball  \
# 160544      7936       1  Chennai Super Kings  Rajasthan Royals    17     1
# 160545      7936       1  Chennai Super Kings  Rajasthan Royals    17     2
# 160546      7936       1  Chennai Super Kings  Rajasthan Royals    17     3
# 160547      7936       1  Chennai Super Kings  Rajasthan Royals    17     4
# 160548      7936       1  Chennai Super Kings  Rajasthan Royals    17     5
#
#             batsman  non_striker    bowler  is_super_over  ...  bye_runs  \
# 160544     MS Dhoni  SW Billings  J Archer              0  ...         0
# 160545  SW Billings     MS Dhoni  J Archer              0  ...         0
# 160546     MS Dhoni  SW Billings  J Archer              0  ...         0
# 160547     MS Dhoni  SW Billings  J Archer              0  ...         0
# 160548     MS Dhoni  SW Billings  J Archer              0  ...         0
#
# ...

# %%
Archer_death_wickets1.groupby(["match_id"])["player_dismissed"].value_counts()
# Out:
# match_id  player_dismissed
# 11148     DJ Bravo            1
# Name: player_dismissed, dtype: int64

# %% [markdown]
# According to dataset Archer takes 1 wicket in death

# %% [markdown]
# # 5

# %%
strike_rate=data1[(data1["batting_team"]=='Rajasthan Royals')&(data1["bowling_team"]=="Chennai Super Kings")&(data1["batsman"]=="SPD Smith")]

# %%
strike_rate.groupby(["match_id"])["batsman_runs"].sum()
# Out:
# match_id
# 467      19
# 494       9
# 533       6
# 563       4
# 11148    31
# 11316    15
# Name: batsman_runs, dtype: int64

# %%
strike_rate.groupby(["match_id"])["ball"].count()
# Out:
# match_id
# 467      20
# 494       8
# 533       7
# 563       6
# 11148    33
# 11316    22
# Name: ball, dtype: int64

# %% [markdown]
# According to dataset smith strike ratre in between 120-130
