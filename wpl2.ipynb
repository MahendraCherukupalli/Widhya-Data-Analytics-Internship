# %% [markdown]
#  <img src="https://github.com/MahendraCherukupalli/The-Sparks-Foundation-Internship/blob/master/wpl_badge1.png?raw=true"/>

# %% [markdown]
# ## Steps:
# - Import Libraries
# - Get the Data
# - Data Preprocessing
# - Train-Test Split
# - Scalling the Data
# - Creating and Training the Model
# - Predictions
# - Residual Analysis
# - Evaluating the modelm

# %% [markdown]
# **Let's get started!**

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
data=pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data1=pd.read_csv("deliveries.csv")
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.shape
# Out:
# (179078, 21)

# %%
data1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# checking for null values...
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Rcb=data["team1"]=='Royal Challengers Bangalore'
Kkr=data["team1"]=='Kolkata Knight Riders'
Rcb1=data["team2"]=='Royal Challengers Bangalore'
Kkr1=data["team2"]=='Kolkata Knight Riders'

# %%
rdf=data[(Rcb & Kkr1)|(Rcb1 & Kkr)]

# %%
rdf
# Out:
#         id  season       city        date                        team1  \
# 26      27    2017    Kolkata  2017-04-23        Kolkata Knight Riders
# 44      45    2017  Bangalore  2017-05-07  Royal Challengers Bangalore
# 59      60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 87      88    2008    Kolkata  2008-05-08        Kolkata Knight Riders
# 133    134    2009     Durban  2009-04-29        Kolkata Knight Riders
# 155    156    2009  Centurion  2009-05-12        Kolkata Knight Riders
# 177    178    2010    Kolkata  2010-03-14  Royal Challengers Bangalore
# 216    217    2010  Bangalore  2010-04-10        Kolkata Knight Riders
# 257    258    2011    Kolkata  2011-04-22        Kolkata Knight Riders
# 290    291    2011  Bangalore  2011-05-14        Kolkata Knight Riders
# 316    317    2012  Bangalore  2012-04-10        Kolkata Knight Riders
# 343    344    2012    Kolkata  2012-04-28        Kolkata Knight Riders
# ...

# %%
rdf.shape
# Out:
# (24, 18)

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]]
# Out:
#                            team1                        team2  \
# 26         Kolkata Knight Riders  Royal Challengers Bangalore
# 44   Royal Challengers Bangalore        Kolkata Knight Riders
# 59         Kolkata Knight Riders  Royal Challengers Bangalore
# 87         Kolkata Knight Riders  Royal Challengers Bangalore
# 133        Kolkata Knight Riders  Royal Challengers Bangalore
# 155        Kolkata Knight Riders  Royal Challengers Bangalore
# 177  Royal Challengers Bangalore        Kolkata Knight Riders
# 216        Kolkata Knight Riders  Royal Challengers Bangalore
# 257        Kolkata Knight Riders  Royal Challengers Bangalore
# 290        Kolkata Knight Riders  Royal Challengers Bangalore
# 316        Kolkata Knight Riders  Royal Challengers Bangalore
# 343        Kolkata Knight Riders  Royal Challengers Bangalore
# 391        Kolkata Knight Riders  Royal Challengers Bangalore
# 440  Royal Challengers Bangalore        Kolkata Knight Riders
# ...

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]].isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %% [markdown]
# # 1

# %%
rdf[(rdf["toss_winner"]=="Royal Challengers Bangalore")&(rdf["toss_decision"]=="bat")]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
rdf["winner"].value_counts()
# Out:
# Kolkata Knight Riders          14
# Royal Challengers Bangalore    10
# Name: winner, dtype: int64

# %% [markdown]
# # 2

# %% [markdown]
# toss winning captain decided bat first

# %% [markdown]
# # 3

# %%
data1.loc[450:600]
# Out:
#      match_id  inning            batting_team           bowling_team  over  \
# 450         2       2  Rising Pune Supergiant         Mumbai Indians    13
# 451         2       2  Rising Pune Supergiant         Mumbai Indians    13
# 452         2       2  Rising Pune Supergiant         Mumbai Indians    14
# 453         2       2  Rising Pune Supergiant         Mumbai Indians    14
# 454         2       2  Rising Pune Supergiant         Mumbai Indians    14
# ..        ...     ...                     ...                    ...   ...
# 596         3       1           Gujarat Lions  Kolkata Knight Riders    17
# 597         3       1           Gujarat Lions  Kolkata Knight Riders    17
# 598         3       1           Gujarat Lions  Kolkata Knight Riders    18
# 599         3       1           Gujarat Lions  Kolkata Knight Riders    18
# 600         3       1           Gujarat Lions  Kolkata Knight Riders    18
#
# ...

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
bat=data1[(data1["batting_team"]=='Kolkata Knight Riders')&(data1["bowling_team"]=="Royal Challengers Bangalore")&(data1["batsman"]=="KD Karthik")]

# %%
bat
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 151113      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151114      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151115      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151117      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151119      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151120      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151121      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151124      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151128      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151132      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# 151133      7896       2  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
bat.shape
# Out:
# (57, 21)

# %%
bat.groupby(["over"])["batsman_runs"].sum()
# Out:
# over
# 8      1
# 9      5
# 10     1
# 11     6
# 12     3
# 13     7
# 14    14
# 15     2
# 16     2
# 17    17
# 18    12
# 19    12
# Name: batsman_runs, dtype: int64

# %%
bat.groupby(["match_id"])["batsman_runs"].sum()
# Out:
# match_id
# 7896     39
# 7922     23
# 11153    20
# Name: batsman_runs, dtype: int64

# %%
bat["batsman_runs"].sum()
# Out:
# 82

# %%
(bat["batsman_runs"].sum())/3
# Out:
# 27.333333333333332

# %%
bat["player_dismissed"].value_counts()
# Out:
# KD Karthik    2
# Name: player_dismissed, dtype: int64

# %% [markdown]
# # 4

# %% [markdown]
# i didnt see any patterns in no of NO balls bowled in each match so i decided it manually

# %% [markdown]
# # 5

# %%
bat1=data1[(data1["batting_team"]=='Royal Challengers Bangalore')&(data1["bowling_team"]=="Kolkata Knight Riders")&(data1["batsman"]=="V Kohli")&(data1["batsman_runs"]==4)]

# %%
bat1
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 31203        134       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 61104        258       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 61113        258       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 61119        258       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 68822        291       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 68836        291       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 74697        317       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 81177        344       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 81184        344       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 81186        344       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 92789        392       2  Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %%
bat1.groupby(["match_id"])["batsman_runs"].count()
# Out:
# match_id
# 134      1
# 258      3
# 291      2
# 317      1
# 344      3
# 392      4
# 441      2
# 468      4
# 506      3
# 550      2
# 606      4
# 624      5
# 7896     1
# 7922     5
# 11153    9
# 11326    9
# Name: batsman_runs, dtype: int64
