# %% [markdown]
#  <img src="https://github.com/MahendraCherukupalli/The-Sparks-Foundation-Internship/blob/master/wpl_badge1.png?raw=true"/>

# %% [markdown]
# ## Steps:
# - Import Libraries
# - Get the Data
# - Data Preprocessing
# - Train-Test Split
# - Scalling the Data
# - Creating and Training the Model
# - Predictions
# - Residual Analysis
# - Evaluating the modelm

# %% [markdown]
# **Let's get started!**

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
data=pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data1=pd.read_csv("deliveries.csv")
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.shape
# Out:
# (179078, 21)

# %%
data1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# checking for null values...
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
Dc=data["team1"]=='Delhi Daredevils'
Csk=data["team1"]=='Chennai Super Kings'
Dc1=data["team2"]=='Delhi Daredevils'
Csk1=data["team2"]=='Chennai Super Kings'

# %%
rdf=data[(Dc & Csk1)|(Dc1 & Csk)]

# %%
rdf.head()
# Out:
#       id  season          city        date                team1  \
# 78    79    2008       Chennai  2008-05-02  Chennai Super Kings
# 86    87    2008         Delhi  2008-05-08     Delhi Daredevils
# 124  125    2009        Durban  2009-04-23     Delhi Daredevils
# 140  141    2009  Johannesburg  2009-05-02  Chennai Super Kings
# 184  185    2010         Delhi  2010-03-19     Delhi Daredevils
#
#                    team2          toss_winner toss_decision  result  \
# 78      Delhi Daredevils  Chennai Super Kings           bat  normal
# 86   Chennai Super Kings  Chennai Super Kings         field  normal
# 124  Chennai Super Kings     Delhi Daredevils           bat  normal
# 140     Delhi Daredevils     Delhi Daredevils         field  normal
# 184  Chennai Super Kings     Delhi Daredevils           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 78            0     Delhi Daredevils            0               8
# ...

# %%
rdf.shape
# Out:
# (18, 18)

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]]
# Out:
#                    team1                team2          toss_winner  \
# 78   Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# 86      Delhi Daredevils  Chennai Super Kings  Chennai Super Kings
# 124     Delhi Daredevils  Chennai Super Kings     Delhi Daredevils
# 140  Chennai Super Kings     Delhi Daredevils     Delhi Daredevils
# 184     Delhi Daredevils  Chennai Super Kings     Delhi Daredevils
# 223  Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# 288  Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# 317  Chennai Super Kings     Delhi Daredevils     Delhi Daredevils
# 363     Delhi Daredevils  Chennai Super Kings  Chennai Super Kings
# 379  Chennai Super Kings     Delhi Daredevils     Delhi Daredevils
# 403  Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# 445  Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# 464  Chennai Super Kings     Delhi Daredevils  Chennai Super Kings
# ...

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]].isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %% [markdown]
# # 1

# %%
rdf[(rdf["toss_winner"]=="Chennai Super Kings")&(rdf["toss_decision"]=="bat")]
# Out:
#       id  season       city        date                team1  \
# 78    79    2008    Chennai  2008-05-02  Chennai Super Kings
# 223  224    2010    Chennai  2010-04-15  Chennai Super Kings
# 288  289    2011    Chennai  2011-05-12  Chennai Super Kings
# 403  404    2013      Delhi  2013-04-18  Chennai Super Kings
# 445  446    2013    Chennai  2013-05-14  Chennai Super Kings
# 464  465    2014  Abu Dhabi  2014-04-21  Chennai Super Kings
# 564  565    2015     Raipur  2015-05-12  Chennai Super Kings
#
#                 team2          toss_winner toss_decision  result  dl_applied  \
# 78   Delhi Daredevils  Chennai Super Kings           bat  normal           0
# 223  Delhi Daredevils  Chennai Super Kings           bat  normal           0
# 288  Delhi Daredevils  Chennai Super Kings           bat  normal           0
# 403  Delhi Daredevils  Chennai Super Kings           bat  normal           0
# 445  Delhi Daredevils  Chennai Super Kings           bat  normal           0
# ...

# %%
rdf["winner"].value_counts()
# Out:
# Chennai Super Kings    12
# Delhi Daredevils        6
# Name: winner, dtype: int64

# %% [markdown]
# according to the dataset CSK win the match

# %% [markdown]
# # 2

# %%
Total_runs=data1[(data1["batting_team"]=='Chennai Super Kings')&(data1["bowling_team"]=="Delhi Daredevils")]

# %%
Total_runs.groupby(["match_id"])["total_runs"].sum()
# Out:
# match_id
# 79      169
# 87      188
# 125     180
# 141     163
# 185     190
# 224     112
# 289     176
# 318     110
# 364     115
# 380     222
# 404     169
# 446     168
# 465     177
# 483     181
# 519     150
# 565     119
# 7923    218
# 7945    130
# Name: total_runs, dtype: int64

# %%
Total_runs.groupby(["match_id"])["total_runs"].sum().mean()
# Out:
# 163.16666666666666

# %% [markdown]
# according to the dataset CSK score average of 164 runs

# %% [markdown]
# # 3

# %%
wickets=data1[(data1["batting_team"]=='Delhi Daredevils')&(data1["bowling_team"]=="Chennai Super Kings")]

# %%
wickets
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 18498         79       2  Delhi Daredevils  Chennai Super Kings     1     1
# 18499         79       2  Delhi Daredevils  Chennai Super Kings     1     2
# 18500         79       2  Delhi Daredevils  Chennai Super Kings     1     3
# 18501         79       2  Delhi Daredevils  Chennai Super Kings     1     4
# 18502         79       2  Delhi Daredevils  Chennai Super Kings     1     5
# ...          ...     ...               ...                  ...   ...   ...
# 162657      7945       1  Delhi Daredevils  Chennai Super Kings    20     2
# 162658      7945       1  Delhi Daredevils  Chennai Super Kings    20     3
# 162659      7945       1  Delhi Daredevils  Chennai Super Kings    20     4
# 162660      7945       1  Delhi Daredevils  Chennai Super Kings    20     5
# 162661      7945       1  Delhi Daredevils  Chennai Super Kings    20     6
#
# ...

# %%
wickets1=wickets[wickets["over"].isin([16,17,18,19,20])]

# %%
wickets1.groupby(["match_id"])["player_dismissed"].count()
# Out:
# match_id
# 79      0
# 87      3
# 125     1
# 141     5
# 185     2
# 224     0
# 289     3
# 364     0
# 380     3
# 404     3
# 446     3
# 465     1
# 483     0
# 519     4
# 565     1
# 7923    1
# 7945    0
# Name: player_dismissed, dtype: int64

# %%
wickets1.groupby(["match_id"])["player_dismissed"].count().mean()
# Out:
# 1.7647058823529411

# %% [markdown]
# According to dataset DC loss average of 2 wickets against Csk in 15-20 overs..

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# # 4

# %%
runs_100=data1[(data1["batting_team"]=='Chennai Super Kings')&(data1["bowling_team"]=="Delhi Daredevils")]

# %%
runs_100
# Out:
#         match_id  inning         batting_team      bowling_team  over  ball  \
# 18372         79       1  Chennai Super Kings  Delhi Daredevils     1     1
# 18373         79       1  Chennai Super Kings  Delhi Daredevils     1     2
# 18374         79       1  Chennai Super Kings  Delhi Daredevils     1     3
# 18375         79       1  Chennai Super Kings  Delhi Daredevils     1     4
# 18376         79       1  Chennai Super Kings  Delhi Daredevils     1     5
# ...          ...     ...                  ...               ...   ...   ...
# 162777      7945       2  Chennai Super Kings  Delhi Daredevils    20     2
# 162778      7945       2  Chennai Super Kings  Delhi Daredevils    20     3
# 162779      7945       2  Chennai Super Kings  Delhi Daredevils    20     4
# 162780      7945       2  Chennai Super Kings  Delhi Daredevils    20     5
# 162781      7945       2  Chennai Super Kings  Delhi Daredevils    20     6
#
# ...

# %%
list1=list(runs_100["total_runs"])

# %%
j=0
r=0
for i in list1:
    j=j+i
    r=r+1
    if j>=100:
        break
print("Balls take to score 100 runs:",(runs_100.iloc[r]["over"]*6)+(runs_100.iloc[r]["ball"]))
# Out:
# Balls take to score 100 runs: 77

# %% [markdown]
# # 5

# %%
No_balls=data1[(data1["batting_team"].isin(['Delhi Daredevils',"Chennai Super Kings"]))&(data1["bowling_team"].isin(['Delhi Daredevils',"Chennai Super Kings"]))]

# %%
No_balls1=No_balls[No_balls["noball_runs"]==1]

# %%
No_balls1.groupby(["match_id"])["noball_runs"].count()
# Out:
# match_id
# 79      4
# 87      2
# 125     1
# 141     1
# 185     1
# 224     2
# 289     1
# 519     1
# 7923    1
# Name: noball_runs, dtype: int64

# %%
No_balls1.groupby(["match_id"])["noball_runs"].count().mean()
# Out:
# 1.5555555555555556

# %% [markdown]
# According to dataset both team bowls average of 2 No ball
