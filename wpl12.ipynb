# %% [markdown]
#  <img src="https://github.com/MahendraCherukupalli/The-Sparks-Foundation-Internship/blob/master/wpl_badge1.png?raw=true"/>

# %% [markdown]
# ## Steps:
# - Import Libraries
# - Get the Data
# - Data Preprocessing
# - Train-Test Split
# - Scalling the Data
# - Creating and Training the Model
# - Predictions
# - Residual Analysis
# - Evaluating the modelm

# %% [markdown]
# **Let's get started!**

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
data=pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data1=pd.read_csv("deliveries.csv")
data1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data1.shape
# Out:
# (179078, 21)

# %%
data1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# checking for null values...
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
RR=data["team1"]=='Rajasthan Royals'
SRH=data["team1"]=='Sunrisers Hyderabad'
RR1=data["team2"]=='Rajasthan Royals'
SRH1=data["team2"]=='Sunrisers Hyderabad'

# %%
rdf=data[(RR & SRH1)|(RR1 & SRH)]

# %%
rdf.head()
# Out:
#       id  season       city        date                team1  \
# 415  416    2013     Jaipur  2013-04-27  Sunrisers Hyderabad
# 448  449    2013  Hyderabad  2013-05-17  Sunrisers Hyderabad
# 454  455    2013      Delhi  2013-05-22  Sunrisers Hyderabad
# 460  461    2014  Abu Dhabi  2014-04-18  Sunrisers Hyderabad
# 486  487    2014  Ahmedabad  2014-05-08  Sunrisers Hyderabad
#
#                 team2          toss_winner toss_decision  result  dl_applied  \
# 415  Rajasthan Royals  Sunrisers Hyderabad           bat  normal           0
# 448  Rajasthan Royals  Sunrisers Hyderabad           bat  normal           0
# 454  Rajasthan Royals  Sunrisers Hyderabad           bat  normal           0
# 460  Rajasthan Royals     Rajasthan Royals         field  normal           0
# 486  Rajasthan Royals     Rajasthan Royals         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# ...

# %%
rdf.shape
# Out:
# (11, 18)

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]]
# Out:
#                    team1                team2          toss_winner  \
# 415  Sunrisers Hyderabad     Rajasthan Royals  Sunrisers Hyderabad
# 448  Sunrisers Hyderabad     Rajasthan Royals  Sunrisers Hyderabad
# 454  Sunrisers Hyderabad     Rajasthan Royals  Sunrisers Hyderabad
# 460  Sunrisers Hyderabad     Rajasthan Royals     Rajasthan Royals
# 486  Sunrisers Hyderabad     Rajasthan Royals     Rajasthan Royals
# 528  Sunrisers Hyderabad     Rajasthan Royals     Rajasthan Royals
# 557  Sunrisers Hyderabad     Rajasthan Royals     Rajasthan Royals
# 639     Rajasthan Royals  Sunrisers Hyderabad  Sunrisers Hyderabad
# 663  Sunrisers Hyderabad     Rajasthan Royals  Sunrisers Hyderabad
# 703     Rajasthan Royals  Sunrisers Hyderabad     Rajasthan Royals
# 740  Sunrisers Hyderabad     Rajasthan Royals     Rajasthan Royals
#
#     toss_decision               winner
# 415           bat     Rajasthan Royals
# 448           bat  Sunrisers Hyderabad
# 454           bat     Rajasthan Royals
# ...

# %%
rdf[["team1","team2","toss_winner","toss_decision","winner"]].isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           0
# dtype: int64

# %% [markdown]
# # 1

# %%
rdf[(rdf["toss_winner"]=="Sunrisers Hyderabad")&(rdf["toss_decision"]=="field")]
# Out:
#        id  season       city      date             team1                team2  \
# 639  7897    2018  Hyderabad  09/04/18  Rajasthan Royals  Sunrisers Hyderabad
#
#              toss_winner toss_decision  result  dl_applied  \
# 639  Sunrisers Hyderabad         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 639  Sunrisers Hyderabad            0               9        S Dhawan
#
#                                          venue      umpire1          umpire2  \
# 639  Rajiv Gandhi International Stadium, Uppal  Nigel Llong  Vineet Kulkarni
#
#       umpire3
# 639  O Nandan

# %%
rdf["winner"].value_counts()
# Out:
# Sunrisers Hyderabad    6
# Rajasthan Royals       5
# Name: winner, dtype: int64

# %% [markdown]
# according to the dataset SRH win the match

# %% [markdown]
# # 2

# %%
rashid=data1[(data1["batting_team"]=='Rajasthan Royals')&(data1["bowling_team"]=="Sunrisers Hyderabad")&(data1["bowler"]=="Rashid Khan")]

# %%
rashid.groupby(["match_id"])["over"].value_counts()
# Out:
# match_id  over
# 7897      8       6
#           12      6
#           16      6
#           18      6
# 7921      8       6
#           14      6
#           16      6
#           18      6
# 11144     4       6
#           9       6
#           13      6
#           15      6
# 11336     4       6
#           7       6
#           10      6
#           14      6
# Name: over, dtype: int64

# %%
rashid1=rashid.fillna(0)

# %%
rashid2=rashid1[rashid1["player_dismissed"]!=0]

# %%
rashid2.groupby(["match_id","over","ball"])["player_dismissed"].count()
# Out:
# match_id  over  ball
# 7897      18    2       1
# 7921      14    6       1
# 11144     4     2       1
# 11336     10    1       1
# Name: player_dismissed, dtype: int64

# %%
rashid=rashid.fillna(0)

# %% [markdown]
# According to dataset Rashid takes average of 10 balls to take his first wicket

# %% [markdown]
# # 3

# %%
warner=data1[(data1["batting_team"]=='Sunrisers Hyderabad')&(data1["bowling_team"]=="Rajasthan Royals")&(data1["batsman"]=="DA Warner")]

# %%
warner["dismissal_kind"].value_counts()
# Out:
# caught     4
# stumped    1
# Name: dismissal_kind, dtype: int64

# %% [markdown]
# According to dataset warner out by catch

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# # 4

# %%
most_runs=data1[(data1["batting_team"]=='Rajasthan Royals')&(data1["bowling_team"]=="Sunrisers Hyderabad")]

# %%
df=pd.DataFrame(most_runs.groupby(["match_id","batsman"])["batsman_runs"].sum())

# %%
df=df.sort_values(by="batsman_runs",ascending=False)

# %%
df
# Out:
#                      batsman_runs
# match_id batsman
# 11144    SV Samson            106
# 416      SR Watson             98
# 11144    AM Rahane             70
# 558      SPD Smith             68
# 7921     AM Rahane             66
# ...                           ...
# 487      AM Rahane              0
# 7921     BA Stokes              0
# 449      SK Trivedi             0
# 7897     K Gowtham              0
# 455      DH Yagnik              0
#
# [85 rows x 1 columns]

# %%
df.groupby(["match_id","batsman"])["batsman_runs"].sum()
# Out:
# match_id  batsman
# 416       AM Rahane         1
#           R Dravid         36
#           SR Watson        98
#           STR Binny         9
# 449       AM Rahane        12
#                            ..
# 11336     A Turner          3
#           AM Rahane        40
#           L Livingstone    44
#           SPD Smith        22
#           SV Samson        53
# Name: batsman_runs, Length: 85, dtype: int64

# %% [markdown]
# according to dataset butler scores high...

# %% [markdown]
# # 5

# %%
No_balls=data1[(data1["batting_team"]=='Sunrisers Hyderabad')&(data1["bowling_team"]=="Rajasthan Royals")]

# %%
No_balls1=No_balls[No_balls["noball_runs"]==1]

# %%
No_balls1.groupby(["match_id"])["noball_runs"].count()
# Out:
# match_id
# 529     1
# 7897    1
# Name: noball_runs, dtype: int64

# %%
No_balls2=data1[(data1["batting_team"]=='Rajasthan Royals')&(data1["bowling_team"]=="Sunrisers Hyderabad")]

# %%
No_balls3=No_balls2[No_balls2["noball_runs"]==1]

# %%
No_balls3.groupby(["match_id"])["noball_runs"].count()
# Out:
# match_id
# 11144    1
# Name: noball_runs, dtype: int64

# %% [markdown]
# According to dataset both team bowls average of 1 No ball
